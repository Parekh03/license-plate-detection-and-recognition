# %% [markdown]
# # Importing dependencies and models

# %%
import numpy as np
import matplotlib.pyplot as plt
import random
import cv2
import easyocr
import pytesseract

# %%
from ultralytics import YOLO
from sort.sort import *

# %%
from util import get_car, read_license_plate, write_csv

# %%
car_model = YOLO("yolov8n.pt")
license_plate_model = YOLO("./license_detector.pt")
mot_tracker = Sort()
reader = easyocr.Reader(['en'], gpu=False)
# Out:
# Using CPU. Note: This module is much faster with a GPU.

# %% [markdown]
# # Steps to make predictions on images

# %% [markdown]
# ### 1. Read an image

# %%
image = cv2.imread("./test images/car-wbs-HR26CH3604_00000.jpeg")

# %% [markdown]
# ### 2. Detect the license plate

# %%
license_detections = license_plate_model(image)
# Out:
# 0: 640x480 (no detections), 323.0ms
# Speed: 14.0ms preprocess, 323.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)

# %%
for detection in license_detections:
    detection.show()

# %% [markdown]
# ### 3. Get the position/coordinates of the license plate

# %%
for detection in license_detections:
        for box in detection.boxes.data.tolist():
            (x1, y1, x2, y2, cnf, class_id) = box

# %% [markdown]
# ### 4. Crop the original image

# %%
license_cropped = image[int(y1): int(y2), int(x1):int(x2), :]

# %%
plt.imshow(cv2.cvtColor(license_cropped, cv2.COLOR_BGR2RGB))
plt.axis("off")
plt.title("Cropped image (license plate)")
plt.show()

# %% [markdown]
# ### 5. Convert the cropped image into grayscale

# %%
license_gray = cv2.cvtColor(license_cropped, cv2.COLOR_BGR2GRAY)

# %%
plt.imshow(cv2.cvtColor(license_gray, cv2.COLOR_BGR2RGB))
plt.axis("off")
plt.title("Gray scaled image (license plate)")
plt.show()

# %% [markdown]
# ### 6. Get the text from license plate using EasyOCR

# %%
detections = reader.readtext(license_gray)

# %%
if detections:
    license_text = detections[0][1]
    score = detections[0][2]

    print(f"\nDetected Text: {license_text}\nConfidence Score: {score}")
# Out:
# Detected Text: HR 26 CH 3604
# Confidence Score: 0.8790917902579659

# %% [markdown]
# # Functions to detect and recognize license plates from images

# %%
def predict_on_img(image, save, image_name, output_dir):
    """
    Predict the license plate text from the given image and optionally save the annotated image.

    Args:
        image (numpy.ndarray): The input image.
        save (bool): Whether to save the annotated image or not.
        image_name (str): The name of the image stored locally. (Only required when save=True)
        output_dir (str): The directory to save the annotated image.

    Returns:
        None
    """
    # Detecting the license plate from the image
    license_detections = license_plate_model(image)

    # Extracting its coordinates/position
    for detection in license_detections:
        for box in detection.boxes.data.tolist():
            (x1, y1, x2, y2, cnf, class_id) = box
            
    # Displaying the original image
    # plt.imshow(cv2.cvtColor(image,cv2.COLOR_BGR2RGB))
    # plt.axis("off")
    # plt.title("Original image")
    # plt.show()
    
    # Cropping the original image to get the license plate
    license_cropped = image[int(y1): int(y2), int(x1):int(x2), :]

    # Displaying the cropped image
    # plt.imshow(cv2.cvtColor(license_cropped, cv2.COLOR_BGR2RGB))
    # plt.axis("off")
    # plt.title("Cropped image (license plate)")
    # plt.show()

    # Converting the license plate to gray scale
    license_gray = cv2.cvtColor(license_cropped, cv2.COLOR_BGR2GRAY)

    # plt.imshow(cv2.cvtColor(license_gray, cv2.COLOR_BGR2RGB))
    # plt.axis("off")
    # plt.title("Gray scaled image (license plate)")
    # plt.show()

    # Thresholding --> optional
    ''' _, license_thresh = cv2.threshold(license_gray, threshold, 255, cv2.THRESH_BINARY_INV)

    plt.imshow(cv2.cvtColor(license_thresh, cv2.COLOR_BGR2RGB))
    plt.axis("off")
    plt.title("Thresholded image (license plate)")
    plt.show() '''

    # Making detections using the EasyOCR reader
    detections = reader.readtext(license_gray)
    
    if detections:
        license_text = detections[0][1]
        score = detections[0][2]

        print(f"\nDetected Text: {license_text}\nConfidence Score: {score}")

        # Drawing bounding box and annotating text on the original image
        bbox = [(x1, y1), (x2, y1), (x2, y2), (x1, y2)]
        annotated_image = draw_bounding_box(image.copy(), bbox, license_text)

        # Displaying the annotated image
        # plt.imshow(cv2.cvtColor(annotated_image,cv2.COLOR_BGR2RGB))
        # plt.title("Annotated image")
        # plt.axis("off")
        # plt.show()

        if save:
            save_annotated_image(annotated_image, image_name, output_dir)
        
    else:
        print("No text detected")

# %%
def draw_bounding_box(image, bbox, text):
    """
    Draw bounding box and text on the image.

    Args:
        image (numpy.ndarray): The original image.
        bbox (list): The bounding box coordinates.
        text (str): The detected text.

    Returns:
        numpy.ndarray: The image with bounding box and text.
    """
    # Convert bounding box to integer coordinates
    bbox = np.array(bbox).astype(int)
    
    # Draw the bounding box
    cv2.polylines(image, [bbox], isClosed=True, color=(0, 255, 0), thickness=2)

    # Get the coordinates for text placement
    x1, y1 = bbox[0]
    x2, y2 = bbox[2]

    # Calculate the width and height of the text box
    (text_width, text_height), baseline = cv2.getTextSize(text, cv2.FONT_HERSHEY_SIMPLEX, 0.9, 2)

    # Draw a filled white rectangle above the bounding box for the text
    text_box_top_left = (x1, y1 - text_height - 10)
    text_box_bottom_right = (x1 + text_width + 10, y1)
    cv2.rectangle(image, text_box_top_left, text_box_bottom_right, (255, 255, 255), cv2.FILLED)

    # Put the detected text on the white rectangle
    text_position = (x1 + 5, y1 - 5)
    cv2.putText(image, text, text_position, cv2.FONT_HERSHEY_SIMPLEX, 0.9, (0, 0, 0), 2)

    return image

# %%
def save_annotated_image(annotated_image, image_name, output_dir):
    # Save the annotated image
    output_path = output_dir + "/" + f'{image_name}.jpg'
    success = cv2.imwrite(output_path, annotated_image)
    if success:
        print(f"Annotated image saved to: {output_path}")
    else:
        print(f"Failed to save annotated image to: {output_path}")

# %%
OUTPUT_DIR = "./output images"

# %%
img = cv2.imread("./test images/9f7c7dce-f9c9-4c95-a053-8f16e6e99466___new_new-maruti-alto-k10-2_625x300_41414071192.jpg.jpeg")

# %%
predict_on_img(img, save=False, image_name="abc", output_dir=OUTPUT_DIR)
# Out:
# 0: 384x640 1 License_Plate, 328.0ms
# Speed: 8.0ms preprocess, 328.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# Detected Text: HR 26 CT 6702
# Confidence Score: 0.47553099476656985

# %%
os.listdir("./test images")
# Out:
# ['03273806-bb1e-48da-8c8b-a0133a90197a___2014-Skoda-Yeti-Test-Drive.jpg.jpeg',
#  '07bd977e-d578-49a2-b345-7cee5a4db6bf___new_1031520d1356604430-skoda-rapid-joins-family-edit-sold-wp_000281.jpg.jpeg',
#  '0c9ebe94-827d-4c74-9950-6816e70d1bab___IMG_8883.jpeg',
#  '15e7c19f-da3c-4f0d-91f3-552afabc8961___41FxrEl7jHL.jpg.jpeg',
#  '23d775eb-842f-4f57-ad7a-affafa21660a___215453-new-2016-maruti-ertiga-granite-grey-zdi-shvs-highway-champion-img_8168.jpg.jpeg',
#  '254b647f-4cb3-46c3-a206-4e70041f4c78___speedex-number-plates-nandanam-chennai-car-number-plate-dealers-33nu2i6.jpg.jpeg',
#  '2adfb5e7-e70a-4749-b5fa-8c233c0d47d9___new_1572920d1478091901-your-favourite-number-plate-font-jetta-german-font.jpg.jpeg',
#  '41de2ad0-3785-488e-9f1f-75b76f446cc7___Maruti-Alto-K10-Photos-2.jpg.jpeg',
#  '49bdf0d9-4e64-41eb-9c19-eabdc4afb051___Maruti-Suzuki-Ciaz-Photos-30.JPG.jpeg',
#  '51d58875-0bdc-4488-84d9-8b7ad5883863___new_Maruti-Suzuki-Ignis-Rear-view-94486.jpg.jpeg',
#  '56b46df3-223c-42c8-a6bf-e95e5bac29cc___9214a754343030395508e104d7948167_large.jpg.jpeg',
#  '5c85a40f-ce81-44b4-82b2-dfdac281217d___new_Skoda-Octavia-1.8-TSI-5.jpg.jpeg',
#  '6bf2730d-82bf-43ac-8802-b61315d85b96___2017-Skoda-Octavia-rear-high-revealed-for-India-images.jpg.jpeg',
#  '6e772b68-a549-44e5-950e-4c376454c4e9___1557295d1474517501-toyota-innova-crysta-official-review-20160921_173216.jpg.jpeg',
#  '7f369852-27b9-4141-8c48-9e88b20743a6___new_Mahindra-Scorpio-Taillamps-Night.JPG.jpeg',
#  '97846647-16f1-4ee2-b260-60774a21cc74___new_Maruti-Suzuki-Swift-Dzire-1.jpg.jpeg',
#  '9ea92991-8fdf-4b46-aea1-bf08ecff247c___new_1107433d1373284570-my-modded-skoda-rapid-now-166-bhp-351-nm-119-whp-per-tonne-hdr_00005_normal.jpg.jpeg',
#  '9f7c7dce-f9c9-4c95-a053-8f16e6e99466___new_new-maruti-alto-k10-2_625x300_41414071192.jpg.jpeg',
#  'acd85f93-544d-494e-b2f3-2d445937bb0b___new_1431956d1446017445-number-plates-merchandise-canvas-ink-gurgaon-edit-closed-thumb_img_4418_1024.jpg.jpeg',
#  'b3e82163-400b-4211-bb99-a5b53fb13a25___new_IMG_8883.jpg.jpeg',
#  'bb210ab4-795c-4b2b-9b6e-4597cbc67375___White-2BPlate.jpeg',
#  'bbf22d00-3dd6-4338-b701-264e0c0c0aff___Maruti-Swift-DZire-Photos-1.jpg.jpeg',
#  'c1d91c5e-128b-41d4-9f9d-ebfbef98b597___High_security_n15816.jpg.jpeg',
#  'ca18d733-ec53-49d9-87aa-a9f6c52cc7bb___VW-Polo-GT-TSI-badge-on-the-grille.jpg.jpeg',
#  'car-wbs-DL10CG4693_00000.jpeg',
#  'car-wbs-GJW115A1138_00000.jpeg',
#  'car-wbs-HR26BP3543_00000.jpeg',
#  'car-wbs-HR26CH3604_00000.jpeg',
#  'car-wbs-HR26CK8571_00000.jpeg',
#  'car-wbs-HR26CM6005_00000.jpeg',
#  'car-wbs-HR26CR3302_00000.jpeg',
#  'car-wbs-HR26CT6702_00001.jpeg',
#  'car-wbs-MH12DE1433_00001.jpeg',
#  'car-wbs-MH12JC2813_00000.jpeg',
#  'car-wbs-MH14DT8831_00000.jpeg',
#  'car-wbs-MH14EH7958_00000.jpeg',
#  'car-wbs-MH14EP4660_00000.jpeg',
#  'car-wbs-MH14EU3498_00000.jpeg',
#  'car-wbs-MH20BY4465_00000.jpeg',
#  'CarLongPlate112_jpg.rf.7840be7370e6a1b935b4fe20f5fce219.jpg',
#  'CarLongPlate122_jpg.rf.59a01e7d297683dee471b5718544e364.jpg',
#  'CarLongPlate129_jpg.rf.da3922f8112965580d685a20bdb266e5.jpg',
#  'CarLongPlate147_jpg.rf.170e168a499edf114f8b2ab8b252cd1a.jpg',
#  'CarLongPlate160_jpg.rf.478b3cd1069b8471c1e15f0052162b3f.jpg',
#  'CarLongPlate161_jpg.rf.4ab56f3945ee7a68fbd5f96c54128b76.jpg',
#  'CarLongPlate179_jpg.rf.d078f6e07bf6f78f6aef3b334bb19e94.jpg',
#  'CarLongPlate212_jpg.rf.0f8747cdb9acd31d92decec0a292b1cb.jpg',
#  'CarLongPlate263_jpg.rf.43da9e19bd7915f07185c8f6eb99d4e3.jpg',
#  'CarLongPlate277_jpg.rf.4300a9f3b5bf80dac5d3350f5fcc72d1.jpg',
#  'CarLongPlate296_jpg.rf.2397837312f2974434b68361260bf84a.jpg',
#  'CarLongPlate50_jpg.rf.90ef5d76dd04a55e526e638adbfb7d4d.jpg',
#  'CarLongPlate61_jpg.rf.04d8012c1a2025ee412968f9340f3704.jpg',
#  'f20708c6-14cd-46ff-b8f1-6faef5fd8d2d___3e7fd381-0ae5-4421-8a70-279ee0ec1c61_Nissan-Terrano-20346.jpg',
#  'fd0140cc-e887-43b8-a439-24877ea77670___Maruti-Suzuki-Baleno-Number-Plates-Design.jpg.jpeg',
#  'SK1.jpg',
#  'SK3.jpg',
#  'video11_1080.jpg',
#  'video11_4640.jpg',
#  'video12_140.jpg',
#  'video2_1750.jpg',
#  'video2_4230.jpg',
#  'video4_2290.jpg',
#  'video4_2610.jpg',
#  'video6_830.jpg',
#  'video_15.jpg']

# %% [markdown]
# ## Saving the output images into a seperate directory

# %%
for image in os.listdir("./test images"):
    img = cv2.imread("./test images/"+image)
    predict_on_img(img,save=True,image_name = image,output_dir=OUTPUT_DIR)
# Out:
# 0: 544x640 1 License_Plate, 394.0ms
# Speed: 31.0ms preprocess, 394.0ms inference, 3.0ms postprocess per image at shape (1, 3, 544, 640)
#
# Detected Text: HH2Ocs9817
# Confidence Score: 0.32078128653423615
# Annotated image saved to: ./output images/03273806-bb1e-48da-8c8b-a0133a90197a___2014-Skoda-Yeti-Test-Drive.jpg.jpeg.jpg
#
# 0: 480x640 1 License_Plate, 348.0ms
# Speed: 10.0ms preprocess, 348.0ms inference, 4.0ms postprocess per image at shape (1, 3, 480, 640)
#
# Detected Text: MH12JC2813
# Confidence Score: 0.8381903760315976
# Annotated image saved to: ./output images/07bd977e-d578-49a2-b345-7cee5a4db6bf___new_1031520d1356604430-skoda-rapid-joins-family-edit-sold-wp_000281.jpg.jpeg.jpg
#
# 0: 448x640 1 License_Plate, 360.0ms
# Speed: 8.0ms preprocess, 360.0ms inference, 3.0ms postprocess per image at shape (1, 3, 448, 640)
#
# Detected Text: MH2OBY36 65
# Confidence Score: 0.4716799509900124
# Annotated image saved to: ./output images/0c9ebe94-827d-4c74-9950-6816e70d1bab___IMG_8883.jpeg.jpg
#
# 0: 352x640 1 License_Plate, 359.0ms
# Speed: 4.0ms preprocess, 359.0ms inference, 2.0ms postprocess per image at shape (1, 3, 352, 640)
#
# Detected Text: DL10CGL693
# Confidence Score: 0.7984088708914466
# Annotated image saved to: ./output images/15e7c19f-da3c-4f0d-91f3-552afabc8961___41FxrEl7jHL.jpg.jpeg.jpg
#
# 0: 640x640 1 License_Plate, 514.0ms
# Speed: 18.0ms preprocess, 514.0ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# Detected Text: TN37 CR 4019
# Confidence Score: 0.9656214506077367
# Annotated image saved to: ./output images/23d775eb-842f-4f57-ad7a-affafa21660a___215453-new-2016-maruti-ertiga-granite-grey-zdi-shvs-highway-champion-img_8168.jpg.jpeg.jpg
#
# 0: 512x640 1 License_Plate, 405.0ms
# Speed: 7.0ms preprocess, 405.0ms inference, 3.0ms postprocess per image at shape (1, 3, 512, 640)
#
# Detected Text: In 45 BA 1065
# Confidence Score: 0.27005285354429837
# Annotated image saved to: ./output images/254b647f-4cb3-46c3-a206-4e70041f4c78___speedex-number-plates-nandanam-chennai-car-number-plate-dealers-33nu2i6.jpg.jpeg.jpg
#
# 0: 320x640 1 License_Plate, 238.0ms
# Speed: 5.0ms preprocess, 238.0ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# Detected Text: HH14EU3498
# Confidence Score: 0.785847226951804
# Annotated image saved to: ./output images/2adfb5e7-e70a-4749-b5fa-8c233c0d47d9___new_1572920d1478091901-your-favourite-number-plate-font-jetta-german-font.jpg.jpeg.jpg
#
# 0: 608x640 1 License_Plate, 402.0ms
# Speed: 11.0ms preprocess, 402.0ms inference, 2.0ms postprocess per image at shape (1, 3, 608, 640)
#
# Detected Text: HR 26CT4063
# Confidence Score: 0.5157251597434285
# Annotated image saved to: ./output images/41de2ad0-3785-488e-9f1f-75b76f446cc7___Maruti-Alto-K10-Photos-2.jpg.jpeg.jpg
#
# 0: 384x640 1 License_Plate, 276.0ms
# Speed: 5.0ms preprocess, 276.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# Detected Text: HR 26 CH 3604
# Confidence Score: 0.8790917902579659
# Annotated image saved to: ./output images/49bdf0d9-4e64-41eb-9c19-eabdc4afb051___Maruti-Suzuki-Ciaz-Photos-30.JPG.jpeg.jpg
#
# 0: 384x640 1 License_Plate, 266.0ms
# Speed: 5.0ms preprocess, 266.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# Detected Text: HR 26 DA 0471
# Confidence Score: 0.8214695337070546
# Annotated image saved to: ./output images/51d58875-0bdc-4488-84d9-8b7ad5883863___new_Maruti-Suzuki-Ignis-Rear-view-94486.jpg.jpeg.jpg
#
# 0: 640x640 2 License_Plates, 460.0ms
# Speed: 14.0ms preprocess, 460.0ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
# No text detected
#
# 0: 448x640 2 License_Plates, 322.0ms
# Speed: 6.0ms preprocess, 322.0ms inference, 4.0ms postprocess per image at shape (1, 3, 448, 640)
#
# Detected Text: M#20cs 194
# Confidence Score: 0.28214491229443156
# Annotated image saved to: ./output images/5c85a40f-ce81-44b4-82b2-dfdac281217d___new_Skoda-Octavia-1.8-TSI-5.jpg.jpeg.jpg
#
# 0: 608x640 1 License_Plate, 335.0ms
# Speed: 11.0ms preprocess, 335.0ms inference, 2.0ms postprocess per image at shape (1, 3, 608, 640)
#
# Detected Text: MH20 EE 7598
# Confidence Score: 0.9905274344578295
# Annotated image saved to: ./output images/6bf2730d-82bf-43ac-8802-b61315d85b96___2017-Skoda-Octavia-rear-high-revealed-for-India-images.jpg.jpeg.jpg
#
# 0: 544x640 1 License_Plate, 298.0ms
# Speed: 11.0ms preprocess, 298.0ms inference, 3.0ms postprocess per image at shape (1, 3, 544, 640)
#
# Detected Text: KLO1KLKLO1
# Confidence Score: 0.7520265105862186
# Annotated image saved to: ./output images/6e772b68-a549-44e5-950e-4c376454c4e9___1557295d1474517501-toyota-innova-crysta-official-review-20160921_173216.jpg.jpeg.jpg
#
# 0: 512x640 1 License_Plate, 388.0ms
# Speed: 9.0ms preprocess, 388.0ms inference, 4.0ms postprocess per image at shape (1, 3, 512, 640)
#
# Detected Text: H 01 BU 5207
# Confidence Score: 0.6906667461900902
# Annotated image saved to: ./output images/7f369852-27b9-4141-8c48-9e88b20743a6___new_Mahindra-Scorpio-Taillamps-Night.JPG.jpeg.jpg
#
# 0: 544x640 1 License_Plate, 286.0ms
# Speed: 8.0ms preprocess, 286.0ms inference, 1.0ms postprocess per image at shape (1, 3, 544, 640)
#
# Detected Text: HR26 BP3543
# Confidence Score: 0.9418599971391637
# Annotated image saved to: ./output images/97846647-16f1-4ee2-b260-60774a21cc74___new_Maruti-Suzuki-Swift-Dzire-1.jpg.jpeg.jpg
#
# 0: 480x640 1 License_Plate, 335.0ms
# Speed: 6.0ms preprocess, 335.0ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# Detected Text: IN07 BU5427
# Confidence Score: 0.24086641485167581
# Annotated image saved to: ./output images/9ea92991-8fdf-4b46-aea1-bf08ecff247c___new_1107433d1373284570-my-modded-skoda-rapid-now-166-bhp-351-nm-119-whp-per-tonne-hdr_00005_normal.jpg.jpeg.jpg
#
# 0: 384x640 1 License_Plate, 264.0ms
# Speed: 6.0ms preprocess, 264.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# Detected Text: HR 26 CT 6702
# Confidence Score: 0.47553099476656985
# Annotated image saved to: ./output images/9f7c7dce-f9c9-4c95-a053-8f16e6e99466___new_new-maruti-alto-k10-2_625x300_41414071192.jpg.jpeg.jpg
#
# 0: 480x640 1 License_Plate, 433.0ms
# Speed: 7.0ms preprocess, 433.0ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# Detected Text: MHD3BS7778
# Confidence Score: 0.6391893200247615
# Annotated image saved to: ./output images/acd85f93-544d-494e-b2f3-2d445937bb0b___new_1431956d1446017445-number-plates-merchandise-canvas-ink-gurgaon-edit-closed-thumb_img_4418_1024.jpg.jpeg.jpg
#
# 0: 416x640 1 License_Plate, 326.0ms
# Speed: 5.0ms preprocess, 326.0ms inference, 3.0ms postprocess per image at shape (1, 3, 416, 640)
#
# Detected Text: MH2OBY36 65
# Confidence Score: 0.7021194200780259
# Annotated image saved to: ./output images/b3e82163-400b-4211-bb99-a5b53fb13a25___new_IMG_8883.jpg.jpeg.jpg
#
# 0: 512x640 1 License_Plate, 299.0ms
# Speed: 7.0ms preprocess, 299.0ms inference, 3.0ms postprocess per image at shape (1, 3, 512, 640)
#
# Detected Text: MHo 1av8866
# Confidence Score: 0.40012849220091595
# Annotated image saved to: ./output images/bb210ab4-795c-4b2b-9b6e-4597cbc67375___White-2BPlate.jpeg.jpg
#
# 0: 544x640 1 License_Plate, 361.0ms
# Speed: 13.0ms preprocess, 361.0ms inference, 1.0ms postprocess per image at shape (1, 3, 544, 640)
#
# Detected Text: HR 26 CM 6005
# Confidence Score: 0.6986762344990438
# Annotated image saved to: ./output images/bbf22d00-3dd6-4338-b701-264e0c0c0aff___Maruti-Swift-DZire-Photos-1.jpg.jpeg.jpg
#
# 0: 480x640 2 License_Plates, 450.0ms
# Speed: 7.0ms preprocess, 450.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# Detected Text: INDI
# Confidence Score: 0.7068948745727539
# Annotated image saved to: ./output images/c1d91c5e-128b-41d4-9f9d-ebfbef98b597___High_security_n15816.jpg.jpeg.jpg
#
# 0: 448x640 1 License_Plate, 288.0ms
# Speed: 7.0ms preprocess, 288.0ms inference, 2.0ms postprocess per image at shape (1, 3, 448, 640)
#
# Detected Text: MH14dT8831
# Confidence Score: 0.4764265265619698
# Annotated image saved to: ./output images/ca18d733-ec53-49d9-87aa-a9f6c52cc7bb___VW-Polo-GT-TSI-badge-on-the-grille.jpg.jpeg.jpg
#
# 0: 352x640 1 License_Plate, 282.0ms
# Speed: 21.0ms preprocess, 282.0ms inference, 6.0ms postprocess per image at shape (1, 3, 352, 640)
#
# Detected Text: DL10CGL693
# Confidence Score: 0.7984088708914466
# Annotated image saved to: ./output images/car-wbs-DL10CG4693_00000.jpeg.jpg
#
# 0: 512x640 1 License_Plate, 449.0ms
# Speed: 7.0ms preprocess, 449.0ms inference, 2.0ms postprocess per image at shape (1, 3, 512, 640)
#
# Detected Text: GJW-4+15-A-1138
# Confidence Score: 0.3307852988297847
# Annotated image saved to: ./output images/car-wbs-GJW115A1138_00000.jpeg.jpg
#
# 0: 544x640 1 License_Plate, 528.0ms
# Speed: 14.0ms preprocess, 528.0ms inference, 3.0ms postprocess per image at shape (1, 3, 544, 640)
#
# Detected Text: HR26 BP3543
# Confidence Score: 0.9418599971391637
# Annotated image saved to: ./output images/car-wbs-HR26BP3543_00000.jpeg.jpg
#
# 0: 384x640 1 License_Plate, 461.0ms
# Speed: 7.0ms preprocess, 461.0ms inference, 55.0ms postprocess per image at shape (1, 3, 384, 640)
#
# Detected Text: HR 26 CH 3604
# Confidence Score: 0.8790917902579659
# Annotated image saved to: ./output images/car-wbs-HR26CH3604_00000.jpeg.jpg
#
# 0: 320x640 1 License_Plate, 347.0ms
# Speed: 5.0ms preprocess, 347.0ms inference, 3.0ms postprocess per image at shape (1, 3, 320, 640)
#
# Detected Text: QR.Z6.CK 8571
# Confidence Score: 0.23450457646993975
# Annotated image saved to: ./output images/car-wbs-HR26CK8571_00000.jpeg.jpg
#
# 0: 544x640 1 License_Plate, 516.0ms
# Speed: 10.0ms preprocess, 516.0ms inference, 3.0ms postprocess per image at shape (1, 3, 544, 640)
#
# Detected Text: HR 26 CM 6005
# Confidence Score: 0.6986762344990438
# Annotated image saved to: ./output images/car-wbs-HR26CM6005_00000.jpeg.jpg
#
# 0: 448x640 1 License_Plate, 372.0ms
# Speed: 6.0ms preprocess, 372.0ms inference, 2.0ms postprocess per image at shape (1, 3, 448, 640)
#
# Detected Text: HR 26 CR 3302
# Confidence Score: 0.7141555748129389
# Annotated image saved to: ./output images/car-wbs-HR26CR3302_00000.jpeg.jpg
#
# 0: 384x640 1 License_Plate, 280.0ms
# Speed: 6.0ms preprocess, 280.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# Detected Text: HR 26 CT 6702
# Confidence Score: 0.47553099476656985
# Annotated image saved to: ./output images/car-wbs-HR26CT6702_00001.jpeg.jpg
#
# 0: 352x640 2 License_Plates, 347.0ms
# Speed: 8.0ms preprocess, 347.0ms inference, 3.0ms postprocess per image at shape (1, 3, 352, 640)
#
# Detected Text: IHI2 DE1433
# Confidence Score: 0.5532368339844302
# Annotated image saved to: ./output images/car-wbs-MH12DE1433_00001.jpeg.jpg
#
# 0: 384x640 1 License_Plate, 270.0ms
# Speed: 6.0ms preprocess, 270.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# Detected Text: MH12JC2813
# Confidence Score: 0.8648590858949111
# Annotated image saved to: ./output images/car-wbs-MH12JC2813_00000.jpeg.jpg
#
# 0: 256x640 3 License_Plates, 249.0ms
# Speed: 4.0ms preprocess, 249.0ms inference, 3.0ms postprocess per image at shape (1, 3, 256, 640)
#
# Detected Text: 14dT 8831
# Confidence Score: 0.6390701480044415
# Annotated image saved to: ./output images/car-wbs-MH14DT8831_00000.jpeg.jpg
#
# 0: 512x640 1 License_Plate, 374.0ms
# Speed: 9.0ms preprocess, 374.0ms inference, 2.0ms postprocess per image at shape (1, 3, 512, 640)
#
# Detected Text: MHH 14EH79581
# Confidence Score: 0.21797549403031305
# Annotated image saved to: ./output images/car-wbs-MH14EH7958_00000.jpeg.jpg
#
# 0: 640x640 1 License_Plate, 468.0ms
# Speed: 12.0ms preprocess, 468.0ms inference, 4.0ms postprocess per image at shape (1, 3, 640, 640)
#
# Detected Text: NHI4EP 4660
# Confidence Score: 0.39316243993872424
# Annotated image saved to: ./output images/car-wbs-MH14EP4660_00000.jpeg.jpg
#
# 0: 384x640 2 License_Plates, 283.0ms
# Speed: 7.0ms preprocess, 283.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# Detected Text: MH14E43498
# Confidence Score: 0.5464762737680278
# Annotated image saved to: ./output images/car-wbs-MH14EU3498_00000.jpeg.jpg
#
# 0: 512x640 1 License_Plate, 393.0ms
# Speed: 9.0ms preprocess, 393.0ms inference, 4.0ms postprocess per image at shape (1, 3, 512, 640)
#
# Detected Text: JBy Ll6s
# Confidence Score: 0.06838917334003694
# Annotated image saved to: ./output images/car-wbs-MH20BY4465_00000.jpeg.jpg
#
# 0: 640x640 1 License_Plate, 460.0ms
# Speed: 12.0ms preprocess, 460.0ms inference, 3.0ms postprocess per image at shape (1, 3, 640, 640)
#
# Detected Text: 6IA 654.74
# Confidence Score: 0.26853296705304236
# Annotated image saved to: ./output images/CarLongPlate112_jpg.rf.7840be7370e6a1b935b4fe20f5fce219.jpg.jpg
#
# 0: 640x640 1 License_Plate, 380.0ms
# Speed: 12.0ms preprocess, 380.0ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# Detected Text: EIF.065.32
# Confidence Score: 0.5119666891164495
# Annotated image saved to: ./output images/CarLongPlate122_jpg.rf.59a01e7d297683dee471b5718544e364.jpg.jpg
#
# 0: 640x640 1 License_Plate, 468.0ms
# Speed: 10.0ms preprocess, 468.0ms inference, 3.0ms postprocess per image at shape (1, 3, 640, 640)
#
# Detected Text: 51077529
# Confidence Score: 0.4822184277810318
# Annotated image saved to: ./output images/CarLongPlate129_jpg.rf.da3922f8112965580d685a20bdb266e5.jpg.jpg
#
# 0: 640x640 1 License_Plate, 429.0ms
# Speed: 9.0ms preprocess, 429.0ms inference, 3.0ms postprocess per image at shape (1, 3, 640, 640)
#
# Detected Text: FIF.07973
# Confidence Score: 0.2569299037931727
# Annotated image saved to: ./output images/CarLongPlate147_jpg.rf.170e168a499edf114f8b2ab8b252cd1a.jpg.jpg
#
# 0: 640x640 1 License_Plate, 351.0ms
# Speed: 17.0ms preprocess, 351.0ms inference, 3.0ms postprocess per image at shape (1, 3, 640, 640)
#
# Detected Text: G04:
# Confidence Score: 0.0764210969209671
# Annotated image saved to: ./output images/CarLongPlate160_jpg.rf.478b3cd1069b8471c1e15f0052162b3f.jpg.jpg
#
# 0: 640x640 1 License_Plate, 465.0ms
# Speed: 9.0ms preprocess, 465.0ms inference, 4.0ms postprocess per image at shape (1, 3, 640, 640)
#
# Detected Text: Eoi2obe0
# Confidence Score: 0.29910707452141333
# Annotated image saved to: ./output images/CarLongPlate161_jpg.rf.4ab56f3945ee7a68fbd5f96c54128b76.jpg.jpg
#
# 0: 640x640 1 License_Plate, 433.0ms
# Speed: 15.0ms preprocess, 433.0ms inference, 3.0ms postprocess per image at shape (1, 3, 640, 640)
#
# Detected Text: [3A*18650
# Confidence Score: 0.227522752798137
# Annotated image saved to: ./output images/CarLongPlate179_jpg.rf.d078f6e07bf6f78f6aef3b334bb19e94.jpg.jpg
#
# 0: 640x640 1 License_Plate, 451.0ms
# Speed: 19.0ms preprocess, 451.0ms inference, 6.0ms postprocess per image at shape (1, 3, 640, 640)
#
# Detected Text: 46]
# Confidence Score: 0.4554800627384432
# Annotated image saved to: ./output images/CarLongPlate212_jpg.rf.0f8747cdb9acd31d92decec0a292b1cb.jpg.jpg
#
# 0: 640x640 1 License_Plate, 353.0ms
# Speed: 10.0ms preprocess, 353.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# Detected Text: E2Y.6490
# Confidence Score: 0.39477745077222265
# Annotated image saved to: ./output images/CarLongPlate263_jpg.rf.43da9e19bd7915f07185c8f6eb99d4e3.jpg.jpg
#
# 0: 640x640 1 License_Plate, 357.0ms
# Speed: 11.0ms preprocess, 357.0ms inference, 3.0ms postprocess per image at shape (1, 3, 640, 640)
#
# Detected Text: 6oa-038.68
# Confidence Score: 0.812398857999243
# Annotated image saved to: ./output images/CarLongPlate277_jpg.rf.4300a9f3b5bf80dac5d3350f5fcc72d1.jpg.jpg
#
# 0: 640x640 1 License_Plate, 574.0ms
# Speed: 14.0ms preprocess, 574.0ms inference, 3.0ms postprocess per image at shape (1, 3, 640, 640)
#
# Detected Text: G1F
# Confidence Score: 0.1857302502121852
# Annotated image saved to: ./output images/CarLongPlate296_jpg.rf.2397837312f2974434b68361260bf84a.jpg.jpg
#
# 0: 640x640 1 License_Plate, 354.0ms
# Speed: 10.0ms preprocess, 354.0ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# Detected Text: F1F:.07973
# Confidence Score: 0.19842962062544134
# Annotated image saved to: ./output images/CarLongPlate50_jpg.rf.90ef5d76dd04a55e526e638adbfb7d4d.jpg.jpg
#
# 0: 640x640 1 License_Plate, 522.0ms
# Speed: 10.0ms preprocess, 522.0ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# Detected Text: E1F31118
# Confidence Score: 0.24040307148683074
# Annotated image saved to: ./output images/CarLongPlate61_jpg.rf.04d8012c1a2025ee412968f9340f3704.jpg.jpg
#
# 0: 448x640 1 License_Plate, 397.0ms
# Speed: 11.0ms preprocess, 397.0ms inference, 3.0ms postprocess per image at shape (1, 3, 448, 640)
#
# Detected Text: RJ 27 TC 0530
# Confidence Score: 0.6607879627684484
# Annotated image saved to: ./output images/f20708c6-14cd-46ff-b8f1-6faef5fd8d2d___3e7fd381-0ae5-4421-8a70-279ee0ec1c61_Nissan-Terrano-20346.jpg.jpg
#
# 0: 352x640 1 License_Plate, 224.0ms
# Speed: 7.0ms preprocess, 224.0ms inference, 3.0ms postprocess per image at shape (1, 3, 352, 640)
#
# Detected Text: KLIOAV6633
# Confidence Score: 0.9529588106865555
# Annotated image saved to: ./output images/fd0140cc-e887-43b8-a439-24877ea77670___Maruti-Suzuki-Baleno-Number-Plates-Design.jpg.jpeg.jpg
#
# 0: 480x640 1 License_Plate, 362.0ms
# Speed: 7.0ms preprocess, 362.0ms inference, 4.0ms postprocess per image at shape (1, 3, 480, 640)
#
# Detected Text: SKOiPa2969
# Confidence Score: 0.08538772251378554
# Annotated image saved to: ./output images/SK1.jpg.jpg
#
# 0: 640x480 1 License_Plate, 398.0ms
# Speed: 7.0ms preprocess, 398.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
#
# Detected Text: SKOIP4ZZ08
# Confidence Score: 0.2839797955006971
# Annotated image saved to: ./output images/SK3.jpg.jpg
#
# 0: 608x640 1 License_Plate, 545.0ms
# Speed: 14.0ms preprocess, 545.0ms inference, 2.0ms postprocess per image at shape (1, 3, 608, 640)
#
# Detected Text: MH 47 Y 1124
# Confidence Score: 0.7300951311452829
# Annotated image saved to: ./output images/video11_1080.jpg.jpg
#
# 0: 608x640 1 License_Plate, 345.0ms
# Speed: 13.0ms preprocess, 345.0ms inference, 4.0ms postprocess per image at shape (1, 3, 608, 640)
#
# Detected Text: NH 01AX 3070
# Confidence Score: 0.7197431512041276
# Annotated image saved to: ./output images/video11_4640.jpg.jpg
#
# 0: 640x544 2 License_Plates, 587.0ms
# Speed: 29.0ms preprocess, 587.0ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 544)
#
# Detected Text: IND
# Confidence Score: 0.9989857184946125
# Annotated image saved to: ./output images/video12_140.jpg.jpg
#
# 0: 608x640 1 License_Plate, 374.0ms
# Speed: 16.0ms preprocess, 374.0ms inference, 2.0ms postprocess per image at shape (1, 3, 608, 640)
#
# Detected Text: I)L.XC.N.6308
# Confidence Score: 0.09784043325129277
# Annotated image saved to: ./output images/video2_1750.jpg.jpg
#
# 0: 384x640 1 License_Plate, 267.0ms
# Speed: 9.0ms preprocess, 267.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# Detected Text: MH 02 BT 6482
# Confidence Score: 0.5039980309463062
# Annotated image saved to: ./output images/video2_4230.jpg.jpg
#
# 0: 576x640 1 License_Plate, 445.0ms
# Speed: 12.0ms preprocess, 445.0ms inference, 3.0ms postprocess per image at shape (1, 3, 576, 640)
#
# Detected Text: MH 01 CT
# Confidence Score: 0.7600312786127442
# Annotated image saved to: ./output images/video4_2290.jpg.jpg
#
# 0: 448x640 1 License_Plate, 339.0ms
# Speed: 10.0ms preprocess, 339.0ms inference, 3.0ms postprocess per image at shape (1, 3, 448, 640)
#
# Detected Text: BU;
# Confidence Score: 0.8456534743309021
# Annotated image saved to: ./output images/video4_2610.jpg.jpg
#
# 0: 384x640 1 License_Plate, 362.0ms
# Speed: 6.0ms preprocess, 362.0ms inference, 5.0ms postprocess per image at shape (1, 3, 384, 640)
#
# Detected Text: MH02 DS9365
# Confidence Score: 0.4714432494707703
# Annotated image saved to: ./output images/video6_830.jpg.jpg
#
# 0: 384x640 1 License_Plate, 237.0ms
# Speed: 8.0ms preprocess, 237.0ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# Detected Text: MH,01
# Confidence Score: 0.5422242980862759
# Annotated image saved to: ./output images/video_15.jpg.jpg
#
# 0: 640x480 1 License_Plate, 335.0ms
# Speed: 10.0ms preprocess, 335.0ms inference, 3.0ms postprocess per image at shape (1, 3, 640, 480)
#
# Detected Text: OD 334
# Confidence Score: 0.728669064562347
# Annotated image saved to: ./output images/WhatsApp Image 2024-05-30 at 12.18.42_6a4b07f2.jpg.jpg
#
# 0: 640x480 (no detections), 373.0ms
# Speed: 10.0ms preprocess, 373.0ms inference, 3.0ms postprocess per image at shape (1, 3, 640, 480)
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# Cell In[36], line 3
#       1 for image in os.listdir("./test images"):
#       2     img = cv2.imread("./test images/"+image)
# ----> 3     predict_on_img(img,save=True,image_name = image,output_dir=OUTPUT_DIR)
#
# Cell In[31], line 29, in predict_on_img(image, save, image_name, output_dir)
#      20         (x1, y1, x2, y2, cnf, class_id) = box
#      22 # Displaying the original image
#      23 # plt.imshow(cv2.cvtColor(image,cv2.COLOR_BGR2RGB))
#      24 # plt.axis("off")
#    (...)
#      27
#      28 # Cropping the original image to get the license plate
# ---> 29 license_cropped = image[int(y1): int(y2), int(x1):int(x2), :]
#      31 # Displaying the cropped image
#      32 # plt.imshow(cv2.cvtColor(license_cropped, cv2.COLOR_BGR2RGB))
#      33 # plt.axis("off")
#    (...)
#      36
#      37 # Converting the license plate to gray scale
#      38 license_gray = cv2.cvtColor(license_cropped, cv2.COLOR_BGR2GRAY)
#
# UnboundLocalError: cannot access local variable 'y1' where it is not associated with a value

# %% [markdown]
# # Detecting and recognizing license plates from video

# %%
# class of vehicles present in the dataset used to train YOLO
# ["car","motorcycle","bus","truck"]
vehicles = [2,3,5,7]

# %%
# Initialize video capture (from a file in this case)
cap = cv2.VideoCapture('./test-video.mp4')

# Define the codec and create VideoWriter object
frame_width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
frame_height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))
out = cv2.VideoWriter('output_video.avi', cv2.VideoWriter_fourcc(*'MJPG'), 30, (frame_width, frame_height))

# Initialize SORT tracker
mot_tracker = Sort()

frame_num = 1
while cap.isOpened() and frame_num <= 700:
    ret, frame = cap.read()
    if not ret:
        break
    frame_num = frame_num + 1
    # Detect vehicles
    detections = car_model(frame)[0]  # Replace with your vehicle detection model
    detections_ = []
    for detection in detections.boxes.data.tolist():
        x1, y1, x2, y2, score, class_id = detection
        if int(class_id) in vehicles:  # Assuming 'vehicles' is a list of vehicle class IDs
            detections_.append([x1, y1, x2, y2, score])

    # Track vehicles
    track_ids = mot_tracker.update(np.asarray(detections_))

    # Detect license plates
    license_plates = license_plate_model(frame)[0]  # Replace with your license plate detection model
    results = {}
    for license_plate in license_plates.boxes.data.tolist():
        x1, y1, x2, y2, score, class_id = license_plate

        # Assign license plate to car
        xcar1, ycar1, xcar2, ycar2, car_id = get_car(license_plate, track_ids)  # Replace with your function

        if car_id != -1:
            # Crop license plate
            license_plate_crop = frame[int(y1):int(y2), int(x1):int(x2), :]

            # Process license plate
            license_plate_crop_gray = cv2.cvtColor(license_plate_crop, cv2.COLOR_BGR2GRAY)
            _, license_plate_crop_thresh = cv2.threshold(license_plate_crop_gray, 64, 255, cv2.THRESH_BINARY_INV)

            # Read license plate number
            license_plate_text, license_plate_text_score = read_license_plate(license_plate_crop_thresh)  # Replace with your OCR function

            if license_plate_text is not None:
                results[car_id] = {
                    'car': {'bbox': [xcar1, ycar1, xcar2, ycar2]},
                    'license_plate': {'bbox': [x1, y1, x2, y2],
                                      'text': license_plate_text,
                                      'bbox_score': score,
                                      'text_score': license_plate_text_score}
                }

    # Draw bounding boxes and overlay text
    for car_id, data in results.items():
        # Draw car bounding box
        car_bbox = data['car']['bbox']
        cv2.rectangle(frame, (int(car_bbox[0]), int(car_bbox[1])), (int(car_bbox[2]), int(car_bbox[3])), (0, 255, 0), 4)

        # Draw license plate bounding box and text
        license_plate_bbox = data['license_plate']['bbox']
        cv2.rectangle(frame, (int(license_plate_bbox[0]), int(license_plate_bbox[1])),
                      (int(license_plate_bbox[2]), int(license_plate_bbox[3])), (0, 0, 255), 4)
        
        # Set font parameters
        font = cv2.FONT_HERSHEY_SIMPLEX
        font_scale = 3
        font_thickness = 10

        # Draw text on the license plate
        cv2.putText(frame, data['license_plate']['text'], (int(license_plate_bbox[0]), int(license_plate_bbox[1] - 10)),
                    font, font_scale, (0, 255, 255), font_thickness, cv2.LINE_AA)

    # Write the frame to the output video
    out.write(frame)

cap.release()
out.release()
# Out:
# 0: 384x640 21 cars, 1 bus, 2 trucks, 337.0ms
# Speed: 11.0ms preprocess, 337.0ms inference, 43.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 License_Plates, 264.0ms
# Speed: 8.0ms preprocess, 264.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 23 cars, 1 bus, 2 trucks, 368.1ms
# Speed: 9.0ms preprocess, 368.1ms inference, 6.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 License_Plates, 267.0ms
# Speed: 8.0ms preprocess, 267.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 22 cars, 1 bus, 2 trucks, 330.0ms
# Speed: 7.0ms preprocess, 330.0ms inference, 7.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 License_Plates, 319.0ms
# Speed: 6.0ms preprocess, 319.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 23 cars, 1 bus, 2 trucks, 280.0ms
# Speed: 7.0ms preprocess, 280.0ms inference, 6.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 License_Plates, 351.0ms
# Speed: 8.0ms preprocess, 351.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 24 cars, 1 bus, 2 trucks, 353.0ms
# Speed: 12.0ms preprocess, 353.0ms inference, 5.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 License_Plates, 293.0ms
# Speed: 7.0ms preprocess, 293.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 22 cars, 1 bus, 2 trucks, 275.1ms
# Speed: 6.0ms preprocess, 275.1ms inference, 5.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 License_Plates, 252.0ms
# Speed: 9.0ms preprocess, 252.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 23 cars, 1 bus, 3 trucks, 375.0ms
# Speed: 9.0ms preprocess, 375.0ms inference, 5.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 License_Plates, 312.0ms
# Speed: 7.0ms preprocess, 312.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 25 cars, 1 bus, 2 trucks, 376.0ms
# Speed: 10.0ms preprocess, 376.0ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 License_Plates, 279.0ms
# Speed: 9.0ms preprocess, 279.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 22 cars, 1 bus, 2 trucks, 349.0ms
# Speed: 6.0ms preprocess, 349.0ms inference, 6.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 License_Plates, 300.0ms
# Speed: 7.0ms preprocess, 300.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 22 cars, 1 bus, 2 trucks, 329.0ms
# Speed: 7.0ms preprocess, 329.0ms inference, 6.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 License_Plates, 267.0ms
# Speed: 8.0ms preprocess, 267.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
